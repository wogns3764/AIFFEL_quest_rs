# %%
# !pip install opencv-python pixellib
# Out:
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.12/site-packages (4.11.0.86)
# Requirement already satisfied: pixellib in /opt/conda/lib/python3.12/site-packages (0.7.1)
# Requirement already satisfied: numpy>=1.21.2 in /opt/conda/lib/python3.12/site-packages (from opencv-python) (2.2.6)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.12/site-packages (from pixellib) (11.2.1)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.12/site-packages (from pixellib) (0.25.2)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.12/site-packages (from pixellib) (3.10.3)
# Requirement already satisfied: imgaug in /opt/conda/lib/python3.12/site-packages (from pixellib) (0.4.0)
# Requirement already satisfied: labelme2coco in /opt/conda/lib/python3.12/site-packages (from pixellib) (0.2.6)
# Requirement already satisfied: imantics in /opt/conda/lib/python3.12/site-packages (from pixellib) (0.1.12)
# Requirement already satisfied: Cython in /opt/conda/lib/python3.12/site-packages (from pixellib) (3.1.2)
# Requirement already satisfied: pyQt5 in /opt/conda/lib/python3.12/site-packages (from pixellib) (5.15.11)
# Requirement already satisfied: fvcore in /opt/conda/lib/python3.12/site-packages (from pixellib) (0.1.5.post20221221)
# Requirement already satisfied: iopath in /opt/conda/lib/python3.12/site-packages (from pixellib) (0.1.10)
# Requirement already satisfied: omegaconf in /opt/conda/lib/python3.12/site-packages (from pixellib) (2.3.0)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.12/site-packages (from pixellib) (3.1.1)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.12/site-packages (from pixellib) (3.3.0)
# Requirement already satisfied: yacs in /opt/conda/lib/python3.12/site-packages (from pixellib) (0.1.8)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.12/site-packages (from pixellib) (0.9.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.12/site-packages (from pixellib) (4.67.1)
# Requirement already satisfied: future in /opt/conda/lib/python3.12/site-packages (from pixellib) (1.0.0)
# Requirement already satisfied: pydot in /opt/conda/lib/python3.12/site-packages (from pixellib) (4.0.1)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.12/site-packages (from pixellib) (0.6)
# Requirement already satisfied: hydra-core in /opt/conda/lib/python3.12/site-packages (from pixellib) (1.3.2)
# Requirement already satisfied: black in /opt/conda/lib/python3.12/site-packages (from pixellib) (26.1.0)
# Requirement already satisfied: click>=8.0.0 in /opt/conda/lib/python3.12/site-packages (from black->pixellib) (8.2.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /opt/conda/lib/python3.12/site-packages (from black->pixellib) (1.1.0)
# Requirement already satisfied: packaging>=22.0 in /opt/conda/lib/python3.12/site-packages (from black->pixellib) (25.0)
# Requirement already satisfied: pathspec>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from black->pixellib) (1.0.3)
# Requirement already satisfied: platformdirs>=2 in /opt/conda/lib/python3.12/site-packages (from black->pixellib) (4.3.8)
# Requirement already satisfied: pytokens>=0.3.0 in /opt/conda/lib/python3.12/site-packages (from black->pixellib) (0.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.12/site-packages (from fvcore->pixellib) (6.0.2)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.12/site-packages (from iopath->pixellib) (4.14.0)
# Requirement already satisfied: portalocker in /opt/conda/lib/python3.12/site-packages (from iopath->pixellib) (3.2.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/conda/lib/python3.12/site-packages (from hydra-core->pixellib) (4.9.3)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.12/site-packages (from imantics->pixellib) (6.0.2)
# Requirement already satisfied: xmljson in /opt/conda/lib/python3.12/site-packages (from imantics->pixellib) (0.2.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.12/site-packages (from imgaug->pixellib) (1.17.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.12/site-packages (from imgaug->pixellib) (1.15.2)
# Requirement already satisfied: imageio in /opt/conda/lib/python3.12/site-packages (from imgaug->pixellib) (2.37.0)
# Requirement already satisfied: Shapely in /opt/conda/lib/python3.12/site-packages (from imgaug->pixellib) (2.1.2)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.12/site-packages (from scikit-image->pixellib) (3.5)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.12/site-packages (from scikit-image->pixellib) (2025.6.11)
# Requirement already satisfied: lazy-loader>=0.4 in /opt/conda/lib/python3.12/site-packages (from scikit-image->pixellib) (0.4)
# Requirement already satisfied: sahi>=0.8.19 in /opt/conda/lib/python3.12/site-packages (from labelme2coco->pixellib) (0.11.36)
# Requirement already satisfied: jsonschema>=2.6.0 in /opt/conda/lib/python3.12/site-packages (from labelme2coco->pixellib) (4.24.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (0.25.1)
# Requirement already satisfied: fire in /opt/conda/lib/python3.12/site-packages (from sahi>=0.8.19->labelme2coco->pixellib) (0.7.1)
# Requirement already satisfied: pybboxes==0.1.6 in /opt/conda/lib/python3.12/site-packages (from sahi>=0.8.19->labelme2coco->pixellib) (0.1.6)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from sahi>=0.8.19->labelme2coco->pixellib) (2.32.4)
# Requirement already satisfied: terminaltables in /opt/conda/lib/python3.12/site-packages (from sahi>=0.8.19->labelme2coco->pixellib) (3.1.10)
# Requirement already satisfied: torch>=2.4.1 in /opt/conda/lib/python3.12/site-packages (from sahi>=0.8.19->labelme2coco->pixellib) (2.7.1+cpu)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (3.13.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.12/site-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (1.14.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (3.1.6)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.12/site-packages (from torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (2025.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch>=2.4.1->sahi>=0.8.19->labelme2coco->pixellib) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->pixellib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib->pixellib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib->pixellib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->pixellib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->pixellib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib->pixellib) (2.9.0.post0)
# Requirement already satisfied: PyQt5-sip<13,>=12.15 in /opt/conda/lib/python3.12/site-packages (from pyQt5->pixellib) (12.18.0)
# Requirement already satisfied: PyQt5-Qt5<5.16.0,>=5.15.2 in /opt/conda/lib/python3.12/site-packages (from pyQt5->pixellib) (5.15.18)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (2025.6.15)

# %%
import cv2
import numpy as np
import torch
import torchvision.transforms as T
from torchvision.models.segmentation import deeplabv3_resnet101
import matplotlib.pyplot as plt
import os

print(cv2.__version__)
# Out:
# 4.11.0

# %%
cat_img_path = "/home/jovyan/work/workplace/Exploration/Ex02/cat.jpg"   # 고양이 이미지를 준비해주세요
sand_img_path = "/home/jovyan/work/workplace/Exploration/Ex02/sand.jpg"   # 사막 배경 이미지를 준비해주세요

cat_img = cv2.imread(cat_img_path)
sand_img = cv2.imread(sand_img_path)

cat_img = cv2.cvtColor(cat_img, cv2.COLOR_BGR2RGB)
sand_img = cv2.cvtColor(sand_img, cv2.COLOR_BGR2RGB)

print(f"원본 고양이 이미지 크기: {cat_img.shape}")
print(f"배경(사막) 이미지 크기: {sand_img.shape}")

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(cat_img)

plt.subplot(1, 2, 2)
plt.imshow(sand_img)

plt.show()
# Out:
# 원본 고양이 이미지 크기: (2668, 2666, 3)
# 배경(사막) 이미지 크기: (1333, 2000, 3)

# %%
model = deeplabv3_resnet101(pretrained=True).eval()

transform = T.Compose([
    T.ToPILImage(),
    T.Resize((520, 520)),  # 모델 입력 크기
    T.ToTensor(),
])

input_tensor = transform(cat_img).unsqueeze(0)

with torch.no_grad():
    output = model(input_tensor)["out"][0]
    output_predictions = output.argmax(0).byte().cpu().numpy()

print(f"추론 마스크 크기 (Before Resize): {output_predictions.shape}")
# Out:
# /opt/conda/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DeepLabV3_ResNet101_Weights.COCO_WITH_VOC_LABELS_V1`. You can also use `weights=DeepLabV3_ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 추론 마스크 크기 (Before Resize): (520, 520)

# %%
model = deeplabv3_resnet101(pretrained=True).eval()

transform = T.Compose([
    T.ToPILImage(),
    T.Resize((520, 520)),  # 모델 입력 크기
    T.ToTensor(),
])

input_tensor = transform(cat_img).unsqueeze(0)

with torch.no_grad():
    output = model(input_tensor)["out"][0]
    output_predictions = output.argmax(0).byte().cpu().numpy()

print(f"추론 마스크 크기 (Before Resize): {output_predictions.shape}")
# Out:
# 추론 마스크 크기 (Before Resize): (520, 520)

# %%
# 마스크를 원본 크기로 Resize
output_predictions_resized = cv2.resize(output_predictions, (cat_img.shape[1], cat_img.shape[0]), interpolation=cv2.INTER_NEAREST)

print(f"추론 마스크 크기 (After Resize): {output_predictions_resized.shape}")
# Out:
# 추론 마스크 크기 (After Resize): (2668, 2666)

# %%
unique_classes = np.unique(output_predictions_resized)
print(f"예측된 클래스 ID: {unique_classes}")
# Out:
# 예측된 클래스 ID: [0 8]

# %%
target_class_id = unique_classes[-1]

seg_map = (output_predictions_resized == target_class_id)
img_mask = seg_map.astype(np.uint8) * 255

plt.imshow(img_mask, cmap='gray')
plt.show()

# %%
# 배경을 고양이 이미지 크기에 맞춤
sand_img_resized = cv2.resize(sand_img, (cat_img.shape[1], cat_img.shape[0]))

# 고양이 부분만 남기고 배경 적용
img_mask_color = cv2.cvtColor(img_mask, cv2.COLOR_GRAY2BGR)  # 3채널 변환
result_img = np.where(img_mask_color == 255, cat_img, sand_img_resized)  # 마스크 기반 합성

plt.imshow(result_img)
plt.show()

# %%
! mkdir -p ~/work/human_segmentation/models
! mkdir -p ~/work/human_segmentation/images
! ln -s ~/data/* ~/work/human_segmentation/images
# Out:
# ln: failed to create symbolic link '/home/jovyan/work/human_segmentation/images/my_image.png': File exists

# %%
# cv2: OpenCV 라이브러리로, 실시간 컴퓨터 비전을 목적으로 한 프로그래밍 라이브러리
# numpy(NumPy): 행렬이나 대규모 다차원 배열을 쉽게 처리할 수 있도록 지원하는 라이브러리. 데이터 구조 외에도 수치 계산을 위해 효율적으로 구현된 기능을 제공
# torch: PyTorch. 딥러닝 및 텐서 연산을 위한 라이브러리. 인공지능 모델을 만들거나 불러와 추론하는 도구
# torchvision: 이미지 변환 및 전처리를 위한 torchvision의 transform 모듈
# deeplabv3_resnet101: 사전 학습된 DeepLabV3 모델. 이미지를 분류하도록 학습된 모델
# matplotlib: 파이썬 프로그래밍 언어 및 수학적 확장 NumPy 라이브러리를 활용한 플로팅 라이브러리로, 데이터 시각화 도구

import cv2
import os
import numpy as np
import torch
import torchvision.transforms as T
from torchvision.models.segmentation import deeplabv3_resnet101
import matplotlib.pyplot as plt

print('슝=3')
# Out:
# 슝=3

# %%
# 준비한 이미지 파일의 경로를 이용하여, 이미지 파일을 읽음
# cv2.imread(경로): 경로에 해당하는 이미지 파일을 읽어서 변수에 저장

home_dir = os.getenv('HOME')
img_path = os.path.join(home_dir, 'work/camera_sticker/images/image2.jpg')
img_orig = cv2.imread(img_path)

print(f"이미지 크기: {img_orig.shape}")

# cv2.cvtColor(입력 이미지, 색상 변환 코드): 입력 이미지의 색상 채널을 변경
# cv2.COLOR_BGR2RGB: 이미지 색상 채널을 변경 (BGR 형식을 RGB 형식으로 변경)
# plt.imshow(): 저장된 데이터를 이미지의 형식으로 표시, 입력은 RGB(A) 데이터 혹은 2D 스칼라 데이터
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html
# plt.show(): 현재 열려있는 모든 figure를 표시 (여기서 figure는 이미지, 그래프 등)
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.show.html
plt.imshow(cv2.cvtColor(img_orig, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# 이미지 크기: (3088, 2316, 3)

# %%
model = deeplabv3_resnet101(pretrained=True).eval()

# %%
transform = T.Compose([
    T.ToPILImage(),
    T.Resize((520, 520)),  # 모델 입력 크기 (고정)
    T.ToTensor(),
])

# %%
input_tensor = transform(cv2.cvtColor(img_orig, cv2.COLOR_BGR2RGB)).unsqueeze(0)

# %%
# %%time
with torch.no_grad():
    output = model(input_tensor)["out"][0]
    output_predictions = output.argmax(0).byte().cpu().numpy()

# 원본 크기로 Resize
output_predictions_resized = cv2.resize(output_predictions, (img_orig.shape[1], img_orig.shape[0]), interpolation=cv2.INTER_NEAREST)
# Out:
# CPU times: user 9.18 s, sys: 202 ms, total: 9.38 s
# Wall time: 9.49 s

# %%
#pascalvoc 데이터의 라벨종류
LABEL_NAMES = [
    'background', 'aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus',
    'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike',
    'person', 'pottedplant', 'sheep', 'sofa', 'train', 'tv'
]
len(LABEL_NAMES)
# Out:
# 21

# %%
plt.imshow(output_predictions_resized, cmap="jet", alpha=0.7)
plt.title("Segmentation Mask (Resized)")
plt.show()

# %%
unique_classes = np.unique(output_predictions_resized)
unique_classes
# Out:
# array([ 0, 15], dtype=uint8)

# %%
for class_id in unique_classes:
    print(LABEL_NAMES[class_id])
# Out:
# background
# person

# %%
# 아래 코드를 이해하지 않아도 좋습니다
# PixelLib에서 그대로 가져온 코드입니다
# 주목해야 할 것은 생성 코드 결과물이예요!

#컬러맵 만들기
colormap = np.zeros((256, 3), dtype=int)
ind = np.arange(256, dtype=int)

for shift in reversed(range(8)):
    for channel in range(3):
        colormap[:, channel] |= ((ind >> channel) & 1) << shift
    ind >>= 3

colormap[:20]  # 생성한 20개의 컬러맵 출력
# Out:
# array([[  0,   0,   0],
#        [128,   0,   0],
#        [  0, 128,   0],
#        [128, 128,   0],
#        [  0,   0, 128],
#        [128,   0, 128],
#        [  0, 128, 128],
#        [128, 128, 128],
#        [ 64,   0,   0],
#        [192,   0,   0],
#        [ 64, 128,   0],
#        [192, 128,   0],
#        [ 64,   0, 128],
#        [192,   0, 128],
#        [ 64, 128, 128],
#        [192, 128, 128],
#        [  0,  64,   0],
#        [128,  64,   0],
#        [  0, 192,   0],
#        [128, 192,   0]])

# %%
colormap[15] #컬러맵 15에 해당하는 배열 출력 (pacalvoc에 LABEL_NAMES 15번째인 사람)
# Out:
# array([192, 128, 128])

# %%
# output의 픽셀 별로 예측된 class가 사람이라면 1(True), 다르다면 0(False)이 됩니다
# 1과 0에 각각 255를 곱하였으므로 사람으로 예측된 픽셀은 255, 그렇지 않은 픽셀은 0
# cmap 값을 변경하면 다른 색상으로 확인이 가능함
seg_map = (output_predictions_resized == 15)  # 클래스 ID 15 (사람)
img_mask = seg_map.astype(np.uint8) * 255  # 255 값으로 변환
color_mask = cv2.applyColorMap(img_mask, cv2.COLORMAP_JET)

plt.imshow(img_mask, cmap='gray')  # 흑백으로 표시
plt.show()

# %%
# 원본 이미지와 마스트를 적당히 합쳐봅니다
# 0.6과 0.4는 두 이미지를 섞는 비율입니다.

img_show = cv2.addWeighted(img_orig, 0.6, color_mask, 0.4, 0.0)

plt.imshow(cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# (13,13)은 blurring kernel size를 뜻합니다
# 다양하게 바꿔보세요
img_orig_blur = cv2.blur(img_orig, (70, 70))

# plt.imshow(): 저장된 데이터를 이미지의 형식으로 표시한다.
# cv2.cvtColor(입력 이미지, 색상 변환 코드): 입력 이미지의 색상 채널을 변경
# cv2.COLOR_BGR2RGB: 원본이 BGR 순서로 픽셀을 읽다보니
# 이미지 색상 채널을 변경해야함 (BGR 형식을 RGB 형식으로 변경)
plt.imshow(cv2.cvtColor(img_orig_blur, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# cv2.cvtColor(입력 이미지, 색상 변환 코드): 입력 이미지의 색상 채널을 변경
# cv2.COLOR_BGR2RGB: 원본이 BGR 순서로 픽셀을 읽다보니
# 이미지 색상 채널을 변경해야함 (BGR 형식을 RGB 형식으로 변경)
img_mask_color = cv2.cvtColor(img_mask, cv2.COLOR_GRAY2BGR)

# cv2.bitwise_not(): 이미지가 반전됩니다. 배경이 0 사람이 255 였으나
# 연산을 하고 나면 배경은 255 사람은 0입니다.
img_bg_mask = cv2.bitwise_not(img_mask_color)

# cv2.bitwise_and()을 사용하면 배경만 있는 영상을 얻을 수 있습니다.
# 0과 어떤 수를 bitwise_and 연산을 해도 0이 되기 때문에
# 사람이 0인 경우에는 사람이 있던 모든 픽셀이 0이 됩니다. 결국 사람이 사라지고 배경만 남아요!
img_bg_blur = cv2.bitwise_and(img_orig_blur, img_bg_mask)
plt.imshow(cv2.cvtColor(img_bg_blur, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# np.where(조건, 참일때, 거짓일때)
# 세그멘테이션 마스크가 255인 부분만 원본 이미지 값을 가지고 오고
# 아닌 영역은 블러된 이미지 값을 사용합니다.
img_concat = np.where(img_mask_color==255, img_orig, img_bg_blur)
# plt.imshow(): 저장된 데이터를 이미지의 형식으로 표시한다.
# cv2.cvtColor(입력 이미지, 색상 변환 코드): 입력 이미지의 색상 채널을 변경
# cv2.COLOR_BGR2RGB: 원본이 BGR 순서로 픽셀을 읽다보니
# 이미지 색상 채널을 변경해야함 (BGR 형식을 RGB 형식으로 변경)
plt.imshow(cv2.cvtColor(img_concat, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Q. 이번에는 사람 부분을 블러로, 배경 부분을 원본으로 출력해볼까요?
# 힌트 : img_mask_color 옵션을 적절히 조정해주고, img_orig, img_orig_blur 를 활용하세요.
img_concat = np.where(img_mask_color == 255, img_orig_blur, img_orig)
plt.imshow(cv2.cvtColor(img_concat, cv2.COLOR_BGR2RGB))
plt.show()

# %%
home_dir = os.getenv('HOME')
img_path = os.path.join(home_dir, 'work/camera_sticker/images/cat.jpg')
img_orig = cv2.imread(img_path)

print(f"이미지 크기: {img_orig.shape}")

plt.imshow(cv2.cvtColor(img_orig, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# 이미지 크기: (2668, 2666, 3)

# %%
model = deeplabv3_resnet101(pretrained=True).eval()

# %%
transform = T.Compose([
    T.ToPILImage(),
    T.Resize((520, 520)),  # 모델 입력 크기 (고정)
    T.ToTensor(),
])

# %%
input_tensor = transform(cv2.cvtColor(img_orig, cv2.COLOR_BGR2RGB)).unsqueeze(0)

# %%
# %%time
with torch.no_grad():
    output = model(input_tensor)["out"][0]
    output_predictions = output.argmax(0).byte().cpu().numpy()

# 원본 크기로 Resize
output_predictions_resized = cv2.resize(output_predictions, (img_orig.shape[1], img_orig.shape[0]), interpolation=cv2.INTER_NEAREST)
# Out:
# CPU times: user 9.52 s, sys: 211 ms, total: 9.73 s
# Wall time: 9.97 s

# %%
#pascalvoc 데이터의 라벨종류
LABEL_NAMES = [
    'background', 'aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus',
    'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike',
    'person', 'pottedplant', 'sheep', 'sofa', 'train', 'tv'
]
len(LABEL_NAMES)
# Out:
# 21

# %%
plt.imshow(output_predictions_resized, cmap="jet", alpha=0.7)
plt.title("Segmentation Mask (Resized)")
plt.show()

# %%
unique_classes = np.unique(output_predictions_resized)
unique_classes
# Out:
# array([0, 8], dtype=uint8)

# %%
for class_id in unique_classes:
    print(LABEL_NAMES[class_id])
# Out:
# background
# cat

# %%
#컬러맵 만들기
colormap = np.zeros((256, 3), dtype=int)
ind = np.arange(256, dtype=int)

for shift in reversed(range(8)):
    for channel in range(3):
        colormap[:, channel] |= ((ind >> channel) & 1) << shift
    ind >>= 3

colormap[:20]  # 생성한 20개의 컬러맵 출력
# Out:
# array([[  0,   0,   0],
#        [128,   0,   0],
#        [  0, 128,   0],
#        [128, 128,   0],
#        [  0,   0, 128],
#        [128,   0, 128],
#        [  0, 128, 128],
#        [128, 128, 128],
#        [ 64,   0,   0],
#        [192,   0,   0],
#        [ 64, 128,   0],
#        [192, 128,   0],
#        [ 64,   0, 128],
#        [192,   0, 128],
#        [ 64, 128, 128],
#        [192, 128, 128],
#        [  0,  64,   0],
#        [128,  64,   0],
#        [  0, 192,   0],
#        [128, 192,   0]])

# %%
colormap[8] #컬러맵 8에 해당하는 배열 출력 (pacalvoc에 LABEL_NAMES 8번째인 고양이)
# Out:
# array([64,  0,  0])

# %%
# output의 픽셀 별로 예측된 class가 고양이라면 1(True), 다르다면 0(False)이 됩니다
# 1과 0에 각각 255를 곱하였으므로 고양이로 예측된 픽셀은 255, 그렇지 않은 픽셀은 0
# cmap 값을 변경하면 다른 색상으로 확인이 가능함
seg_map = (output_predictions_resized == 8)  # 클래스 ID 8 (고양이)
img_mask = seg_map.astype(np.uint8) * 255  # 255 값으로 변환
color_mask = cv2.applyColorMap(img_mask, cv2.COLORMAP_JET)

plt.imshow(img_mask, cmap='gray')  # 흑백으로 표시
plt.show()

# %%
# 원본 이미지와 마스크를 적당히 합쳐봅니다
# 0.6과 0.4는 두 이미지를 섞는 비율입니다.

img_show = cv2.addWeighted(img_orig, 0.6, color_mask, 0.4, 0.0)

plt.imshow(cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# (13,13)은 blurring kernel size를 뜻합니다
# 다양하게 바꿔보세요
img_orig_blur = cv2.blur(img_orig, (70, 70))

# plt.imshow(): 저장된 데이터를 이미지의 형식으로 표시한다.
# cv2.cvtColor(입력 이미지, 색상 변환 코드): 입력 이미지의 색상 채널을 변경
# cv2.COLOR_BGR2RGB: 원본이 BGR 순서로 픽셀을 읽다보니
# 이미지 색상 채널을 변경해야함 (BGR 형식을 RGB 형식으로 변경)
plt.imshow(cv2.cvtColor(img_orig_blur, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# cv2.cvtColor(입력 이미지, 색상 변환 코드): 입력 이미지의 색상 채널을 변경
# cv2.COLOR_BGR2RGB: 원본이 BGR 순서로 픽셀을 읽다보니
# 이미지 색상 채널을 변경해야함 (BGR 형식을 RGB 형식으로 변경)
img_mask_color = cv2.cvtColor(img_mask, cv2.COLOR_GRAY2BGR)

# cv2.bitwise_not(): 이미지가 반전됩니다. 배경이 0 사람이 255 였으나
# 연산을 하고 나면 배경은 255 고양이는 0입니다.
img_bg_mask = cv2.bitwise_not(img_mask_color)

# cv2.bitwise_and()을 사용하면 배경만 있는 영상을 얻을 수 있습니다.
# 0과 어떤 수를 bitwise_and 연산을 해도 0이 되기 때문에
# 고양이가 0인 경우에는 고양이가 있던 모든 픽셀이 0이 됩니다. 결국 고양이가 사라지고 배경만 남아요!
img_bg_blur = cv2.bitwise_and(img_orig_blur, img_bg_mask)
plt.imshow(cv2.cvtColor(img_bg_blur, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# np.where(조건, 참일때, 거짓일때)
# 세그멘테이션 마스크가 255인 부분만 원본 이미지 값을 가지고 오고
# 아닌 영역은 블러된 이미지 값을 사용합니다.
img_concat = np.where(img_mask_color==255, img_orig, img_bg_blur)
# plt.imshow(): 저장된 데이터를 이미지의 형식으로 표시한다.
# cv2.cvtColor(입력 이미지, 색상 변환 코드): 입력 이미지의 색상 채널을 변경
# cv2.COLOR_BGR2RGB: 원본이 BGR 순서로 픽셀을 읽다보니
# 이미지 색상 채널을 변경해야함 (BGR 형식을 RGB 형식으로 변경)
plt.imshow(cv2.cvtColor(img_concat, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Q. 이번에는 고양이 부분을 블러로, 배경 부분을 원본으로 출력해볼까요?
# 힌트 : img_mask_color 옵션을 적절히 조정해주고, img_orig, img_orig_blur 를 활용하세요.
img_concat = np.where(img_mask_color == 255, img_orig_blur, img_orig)
plt.imshow(cv2.cvtColor(img_concat, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 인물 모드(아웃포커싱/배경합성) 구현 보고서
#
# ## 1. 프로젝트 개요
# - **목표**
#   Semantic Segmentation 모델을 활용하여 인물 영역을 분리하고, 배경 흐림 또는 배경 교체를 적용한 인물 모드 이미지를 생성한다.
#
# - **사용 기술**
#   - OpenCV
#   - NumPy
#   - PyTorch
#   - Torchvision (DeepLabV3)
#
# - **수행 단계**
#   - Step 1: 인물 모드 구현
#   - Step 2: 결과 이미지 문제점 분석
#   - Step 3: 문제 해결 방안 제안
#
# ---
#
# ## 2. Step 2. 사진에서 문제점 찾기
#
# ### 2.1 분석 대상 이미지
# - 원본 이미지
#
# <img src="./image4.PNG" width="300">
#
#
# - 인물 모드 결과 이미지
#
# <img src="./image5.PNG" width="300">
#
# ---
# ### 2.1.2 분석 대상 이미지2
# -원본 이미지
#
# <img src="./image1.PNG" width="300">
#
#
#
# -배경 교체 결과
#
# <img src="./image2.PNG" width="300">
#
# ### 2.2 발견된 문제점 1
#
# - **문제 설명**
#   인물이 아닌 배경 영역이 인물로 잘못 분류되어 배경 교체 또는 블러가 적용되지 않았다.
#
# - **문제 발생 위치**
#   목 주변 의상 및 배경 경계 영역, 고양이 테두리 부분
#
# - **시각적 증거**
#
# <img src="./image3.PNG" width="300">
#
# <img src="./image6.PNG" width="300">
#
# - **원인 추정**
#   - Semantic Segmentation 모델이 배경과 인물의 질감·색상이 유사한 경우 혼동
#   - 픽셀 단위 분류 특성상 객체 단위 구분이 어려움
#
#
# ---
#
# ### 2.3 문제 요약
# - 인물과 배경 경계에서 오분류 발생
# - 디테일한 영역 인식 성능 부족
# - 단순 마스크 합성으로 인해 경계가 부자연스러움
#
# ---
#
# ## 3. Step 3. 해결 방법 제안
#
# ### 3.1 문제 발생의 근본 원인
# - Semantic Segmentation은 픽셀 단위 클래스 분류 방식으로, 머리카락이나 얇은 객체 표현에 한계가 있다.
# - 고정된 입력 크기로 인한 리사이즈 과정에서 디테일 정보가 손실된다.
# - 마스크를 이진(binary) 형태로 사용하여 경계가 단절되어 보인다.
#
# ---
#
# ### 3.2 해결 방안 : 블러 적용 방식 점검
#
# - 현재는 마스크 값이 255인 영역을 기준으로
#   인물과 배경을 나누고 있다.
# - 마스크가 조금이라도 잘못되면
#   배경임에도 블러가 적용되지 않는 영역이 생긴다.
# - 따라서 블러 문제를 해결하려면
#   블러 코드 수정 이전에
#   마스크 품질을 먼저 개선하는 것이 더 중요하다고 판단된다.
# - 마스크 품질을 개선하는 방안으로 아래와 같은 코드를 적용해본다.
#
# ```python
# kernel = np.ones((15,15), np.uint8) #숫자 키우면 더 많이 깎임.
# img_mask = cv2.erode(img_mask, kernel, iterations=1)
# ```
#
# 이 코드를 활용하면 주변 부분이 조금씩 깍인다.
#
# ## 코드적용 결과 비교
#
# ### 원본이미지
#
# <img src="./image2.PNG" width="300">
#
#
# ### 코드적용결과
#
# <img src="./image7.PNG" width="250">
#
#
#
# ---
#
# ## 4. 결론
# Semantic Segmentation 기반 인물 모드는 간단한 구현이 가능하지만, 경계 정확도와 자연스러움에서 한계가 존재한다.
# 후처리 기법과 합성 방식 개선을 통해 품질을 향상시킬 수 있으며, 고급 기술을 적용할수록 실제 카메라 인물 모드에 가까운 결과를 얻을 수 있다.
